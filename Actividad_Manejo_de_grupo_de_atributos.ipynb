# %% [markdown]
# <a href="https://colab.research.google.com/github/WJuniorF/Entregas_POO/blob/main/Actividad_Manejo_de_grupo_de_atributos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Objetivo: prácticas la utilización de instrucciones repetitivas para el manejo de estructuras contenedoras en Python, en el contexto de la programación orientada a objetos.
#
# Enunciado: considere el caso de estudio de las notas de un curso que se presentó anteriormente en el documento, donde se planteaba el siguiente modelo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cuya implementación en Python era la siguiente

# %%
class Estudiante:
    def __init__(self, id, nombre, nota):
        self.id = id
        self.nombre = nombre
        self.nota = nota

class Curso:
    def __init__(self):
        self.estudiantes = []

    def agregar_estudiante(self, id, nombre, nota):
        self.estudiantes.append(Estudiante(id, nombre, nota))

# %% [markdown]
# A continuación, escriba dos métodos de la clase Curso para hacer lo siguiente:
#
# - Método notas_a_cero: este método debe reemplazar todas las notas del curso por 0, hasta que aparezca la primera nota superior a 3.0.
# - Método nota_mediana: este método debe calcular y retorna una nota del curso (si hay varias que lo cumplan puede retornar cualquiera) tal que la mitad de las notas sean menores o iguales a ella.
# Nota: la idea es que intente escribir los métodos y guardarlos, ya que los vamos a analizar en la sesión que tendremos en la oficina virtual.
